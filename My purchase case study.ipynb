# %% [markdown]
# # PURCHASE CASE STUDY

# %% [markdown]
# ### Tasks To Be Performed:
# ###### 1. Perform a Detailed EDA for the Data with inferences from each of the actions.
#
# ###### 2. Using Statistical Analysis, find out statistical evidence for the following:
# a. It was observed that the average purchase made by the Men of the age 18-25
# was 10000. Is it still the same?
#
# b. It was observed that the percentage of women of the age that spend more than
# 10000 was 35%. Is it still the same?
#
# c. Is the average purchase made by men and women of the age 18-25 same?
#
# d. Is the percentage of men who have spent more than 10000 the same for the
# ages 18-25 and 26-35

# %% [markdown]
# ### Dataset used is "train (23).csv"
# It consists of 263015 rows and 12 columns.
#
# Given below are the column names:
#
#     1-User_ID
#     2-Product_ID
#     3-Gender
#     4-Age
#     5-Occupation
#     6-City_Category
#     7-Stay_In_Current_City_Years
#     8-Marital_Status
#     9-Product_Category_1
#     10-Product_Category_2
#     11-Product_Category_3
#     12-Purchase

# %% [markdown]
# # Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv('train (23).csv')
data
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17        10.0             A
# 1       1000001  P00248942      F   0-17        10.0             A
# 2       1000001  P00087842      F   0-17        10.0             A
# 3       1000001  P00085442      F   0-17        10.0             A
# 4       1000002  P00285442      M    55+        16.0             C
# ...         ...        ...    ...    ...         ...           ...
# 263010  1004473  P00041942      M  36-45         1.0             B
# 263011  1004473  P00115142      M  36-45         1.0             B
# 263012  1004473  P00188442      M  36-45         1.0             B
# 263013  1004473  P00119442      M  36-45         1.0             B
# 263014       10        NaN    NaN    NaN         NaN           NaN
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2             0.0                 3.0
# ...

# %%
data['Gender'].value_counts()
# Out:
# M    198488
# F     64526
# Name: Gender, dtype: int64

# %%
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17        10.0             A
# 1  1000001  P00248942      F  0-17        10.0             A
# 2  1000001  P00087842      F  0-17        10.0             A
# 3  1000001  P00085442      F  0-17        10.0             A
# 4  1000002  P00285442      M   55+        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
data.shape
# Out:
# (263015, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263015 entries, 0 to 263014
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     263015 non-null  int64
#  1   Product_ID                  263014 non-null  object
#  2   Gender                      263014 non-null  object
#  3   Age                         263014 non-null  object
#  4   Occupation                  263014 non-null  float64
#  5   City_Category               263014 non-null  object
#  6   Stay_In_Current_City_Years  263014 non-null  object
#  7   Marital_Status              263014 non-null  float64
#  8   Product_Category_1          263014 non-null  float64
#  9   Product_Category_2          181501 non-null  float64
#  10  Product_Category_3          80582 non-null   float64
#  11  Purchase                    263014 non-null  float64
# dtypes: float64(6), int64(1), object(5)
# ...

# %%
#checking the number of null values
data.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         1
# Gender                             1
# Age                                1
# Occupation                         1
# City_Category                      1
# Stay_In_Current_City_Years         1
# Marital_Status                     1
# Product_Category_1                 1
# Product_Category_2             81514
# Product_Category_3            182433
# Purchase                           1
# dtype: int64

# %%
#removing null value from gender
data=data.dropna(subset=['Gender'])

# %%
#filling the null values with mean
data['Product_Category_2']=data['Product_Category_2'].fillna(data['Product_Category_2'].mean())
data['Product_Category_3']=data['Product_Category_3'].fillna(data['Product_Category_3'].mean())

# %%
data.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
data.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
data['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
data['Product_ID'].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00321242',
#        'P00314742', 'P00236242'], dtype=object)

# %%
data['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
data['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
data['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
data['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
data['Marital_Status'].unique()
# Out:
# array([0., 1.])

# %%
#label encoding on the categorical columns
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()

# %%
data['User_ID']=LE.fit_transform(data['User_ID'])
data['Product_ID']=LE.fit_transform(data['Product_ID'])
data['Gender']=LE.fit_transform(data['Gender'])
data['Age']=LE.fit_transform(data['Age'])
data['City_Category']=LE.fit_transform(data['City_Category'])
data['Stay_In_Current_City_Years']=LE.fit_transform(data['Stay_In_Current_City_Years'])

# %%
data['Marital_Status']=LE.fit_transform(data['Marital_Status'])

# %%
data.head()
# Out:
#    User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 0        0         647       0    0        10.0              0
# 1        0        2304       0    0        10.0              0
# 2        0         814       0    0        10.0              0
# 3        0         790       0    0        10.0              0
# 4        1        2657       1    6        16.0              2
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                 3.0
# 1                           2               0                 1.0
# 2                           2               0                12.0
# 3                           2               0                12.0
# 4                           4               0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0            9.844756           12.658298    8370.0
# 1            6.000000           14.000000   15200.0
# ...

# %%
data.describe()
# Out:
#              User_ID     Product_ID         Gender            Age  \
# count  263014.000000  263014.000000  263014.000000  263014.000000
# mean     2867.074680    1637.825542       0.754667       2.494742
# std      1661.229012     973.517929       0.430285       1.354666
# min         0.000000       0.000000       0.000000       0.000000
# 25%      1413.000000     885.000000       1.000000       2.000000
# 50%      2892.000000    1583.000000       1.000000       2.000000
# 75%      4223.000000    2461.000000       1.000000       3.000000
# max      5890.000000    3506.000000       1.000000       6.000000
#
#           Occupation  City_Category  Stay_In_Current_City_Years  \
# count  263014.000000  263014.000000               263014.000000
# mean        8.083558       1.039199                    1.859654
# std         6.524052       0.758923                    1.290596
# min         0.000000       0.000000                    0.000000
# ...

# %%
data.shape
# Out:
# (263014, 12)

# %%
data['User_ID'].unique()
# Out:
# array([   0,    1,    2, ..., 4008, 5253, 1484], dtype=int64)

# %% [markdown]
# # VISUALIZATION

# %%
sns.countplot(data=data,x='Gender')
plt.show()

# %% [markdown]
# From this it is clear that purchases made by males are greater than that of females.

# %%
#Age
sns.countplot(data=data,x='Age',hue='Gender')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #From this, it is clear that 2nd category age group(i.e, 26-35 age group) purchased more.
#
# #Also, category 0(i.e,0-17 age group) purchased less.
#
# #In both cases,males purchased more than females.

# %%
sns.countplot(data=data,x='Marital_Status',hue='Gender')
plt.show()

# %%
data['Marital_Status'].value_counts()
# Out:
# 0    155524
# 1    107490
# Name: Marital_Status, dtype: int64

# %% [markdown]
# #Unmarried customers are greater than married customers.
#
# #The gender ratio in unmarried customers are different.There is a great diference in count between males and females, i.e, unmarried males are greater than females
#
# #Also, the married customers have higher number of males in the lot.

# %%
sns.countplot(data=data,x='Product_Category_1')
plt.show()

# %% [markdown]
# #The product_category_1 sees a great rise of product category 1 and diminishes with the other products.
# The other considerable categories are 5, 8, 11, 2, 3, etc.

# %%
data['Product_Category_1'].value_counts()
# Out:
# 5.0     72899
# 1.0     67659
# 8.0     54987
# 11.0    11685
# 2.0     11528
# 3.0      9729
# 6.0      9684
# 4.0      5681
# 16.0     4727
# 15.0     3025
# 13.0     2636
# 10.0     2436
# 12.0     1871
# 7.0      1782
# 18.0     1481
# 14.0      722
# 17.0      289
# 9.0       193
# Name: Product_Category_1, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=data,x='Product_Category_2')
plt.show()

# %% [markdown]
# #The product_category_2 sees a great rise of product category 9.844756 and diminishes with the other products.
# The other considerable categories are 8, 14, 2,16,15, etc.

# %%
data['Product_Category_2'].value_counts()
# Out:
# 9.844756     81513
# 8.000000     30889
# 14.000000    26570
# 2.000000     23667
# 16.000000    20935
# 15.000000    18240
# 5.000000     12659
# 4.000000     12427
# 6.000000      7937
# 11.000000     6836
# 17.000000     6412
# 13.000000     5079
# 9.000000      2754
# 12.000000     2675
# 3.000000      1403
# 10.000000     1385
# 18.000000     1329
# 7.000000       304
# Name: Product_Category_2, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=data,x='Product_Category_3')
plt.show()

# %% [markdown]
# #The product_category_3 sees a great rise of product category 12.658298 and diminishes with the other products.
# The other considerable categories are 16, 15, 14, 17,5, etc.

# %%
data['Product_Category_3'].value_counts()
# Out:
# 12.658298    182432
# 16.000000     15706
# 15.000000     13448
# 14.000000      8908
# 17.000000      8135
# 5.000000       8068
# 8.000000       6064
# 9.000000       5691
# 12.000000      4479
# 13.000000      2584
# 6.000000       2349
# 18.000000      2213
# 4.000000        918
# 11.000000       893
# 10.000000       828
# 3.000000        298
# Name: Product_Category_3, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=data,x='Occupation')
plt.show()

# %% [markdown]
# #Occupation also sees a constant balance with 4 topping the chart, and other categories in the considerable amount with 0,1,2,7,12,17,20

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=data,x='Stay_In_Current_City_Years')
plt.show()

# %% [markdown]
# #Majority of the customers have stayed a year in the city

# %%
sns.distplot(data['Purchase'])
plt.show()

# %% [markdown]
# #Purchases is not accumulated in a range, rather varies in different intervals.

# %% [markdown]
# # CORRELATION

# %%
spearman_corr=data.corr()
pearson_corr=data.corr(method='pearson')
kendel_corr=data.corr(method='kendall')

# %%
plt.figure(figsize=(10,5))
sns.heatmap(spearman_corr,annot=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(pearson_corr,annot=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(kendel_corr,annot=True)
plt.show()

# %% [markdown]
# #From this it is clear tnat Product_Category_1 and Product_Category_2 is highly correlated
#
# #And Purchase and Product_Category_1 is least correlated

# %% [markdown]
# # STATISTICAL ANALYSIS

# %% [markdown]
# ### One Sample Test For Mean¶
# Let's Suppose, it was observed that the average purchase made by the Men of the age 18-25 was 10000. Is it still the same?

# %%
#null hypothesis : the mean is 10000
#alternate hypothesis : the mean is 1000

# %%
data['Age'].unique()
# Out:
# array([0, 6, 2, 4, 5, 3, 1])

# %%
data['Gender'].unique()
# Out:
# array([0, 1])

# %%
new_data=data.loc[(data['Age']==1) & (data['Gender']==1)]
new_data
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 97           20        2024       1    1        16.0              1
# 98           21        3261       1    1        15.0              0
# 99           21        1954       1    1        15.0              0
# 100          21        1792       1    1        15.0              0
# 101          21        1020       1    1        15.0              0
# ...         ...         ...     ...  ...         ...            ...
# 262767     4333        1311       1    1        18.0              1
# 262951     4352        2880       1    1         4.0              0
# 262952     4352        1296       1    1         4.0              0
# 262953     4352        2733       1    1         4.0              0
# 262954     4352        1424       1    1         4.0              0
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 97                               0               0                 3.0
# ...

# %%
new_data.shape
# Out:
# (36332, 12)

# %%
sample_size=1000
sample=new_data.sample(sample_size,random_state=0)
sample
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 132607     2333        2939       1    1         7.0              2
# 202112     1162        2766       1    1         4.0              2
# 238551      792        2129       1    1         4.0              2
# 73984      5256        2755       1    1         0.0              0
# 258980     3783        2047       1    1         4.0              0
# ...         ...         ...     ...  ...         ...            ...
# 59883      3179         599       1    1        11.0              2
# 36794      5523         996       1    1         4.0              2
# 90413      1850        1292       1    1         1.0              1
# 189990     5214         917       1    1         5.0              0
# 181729     3939        1235       1    1         3.0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 132607                           1               0                 4.0
# ...

# %%
new_data.mean()
# Out:
# User_ID                       2592.904519
# Product_ID                    1603.327260
# Gender                           1.000000
# Age                              1.000000
# Occupation                       6.948062
# City_Category                    1.006193
# Stay_In_Current_City_Years       1.851288
# Marital_Status                   0.199714
# Product_Category_1               4.884124
# Product_Category_2               9.561824
# Product_Category_3              12.597102
# Purchase                      9440.512276
# dtype: float64

# %%
pur_popmean=9440.512276

# %%
pur_sampmean=sample['Purchase'].mean()
pur_sampmean
# Out:
# 9533.235

# %%
#one_sample test
from scipy.stats import ttest_1samp
t_stat,p_value=ttest_1samp(sample['Purchase'],pur_popmean)
print('t_stat: ',t_stat)
print('p_value: ',p_value)
# Out:
# t_stat:  0.5713383757121644
# p_value:  0.5678988029395584

# %% [markdown]
# #### P-value is greater than 0.05, so we accept the null hypothesis.
# #### Therefore, the mean purchase for men aged 18-25 is 10000 and it is still the same.

# %% [markdown]
# ### One Sample Test for Proportion
#  Let's Suppose, It was observed that the percentage of women that spend more than 10000 was 35%. Is it still the same?

# %%
#Null hypoyhesis: proportion is 0.35
#Alternate hypothesis: proportion is not equal to 0.35

# %%
new_data2=data.loc[data['Purchase']>10000]
new_data2
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 1             0        2304       0    0        10.0              0
# 5             2        1768       1    2        15.0              0
# 6             3        1684       1    4         7.0              1
# 7             3        3213       1    4         7.0              1
# 8             3        3481       1    4         7.0              1
# ...         ...         ...     ...  ...         ...            ...
# 262997     4359        2433       0    4        16.0              1
# 263001     4359        1921       0    4        16.0              1
# 263002     4359        1665       0    4        16.0              1
# 263003     4359        3209       0    4        16.0              1
# 263011     4360        1015       1    3         1.0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                                2               0                 1.0
# ...

# %%
new_data2.shape
# Out:
# (91057, 12)

# %%
new_data2['Gender'].value_counts()
# Out:
# 1    72372
# 0    18685
# Name: Gender, dtype: int64

# %%
#No of women in the sample
num_fem=new_data2['Gender'].value_counts()[0]
num_fem
# Out:
# 18685

# %%
#number of observations
no_obs=len(new_data2['Gender'])
no_obs
# Out:
# 91057

# %%
#hypothesised value
p0 = 0.35

# %%
new_data2['Gender'].value_counts()[0]/no_obs
# Out:
# 0.20520113774888257

# %%
#one sample z test
from statsmodels.stats.proportion import proportions_ztest
z_stat,p_value=proportions_ztest(count=num_fem,nobs=no_obs,value=p0,alternative='two-sided',prop_var=False)
print('z_stat: ',z_stat)
print('p_value: ',p_value)
# Out:
# z_stat:  -108.19403500300525
# p_value:  0.0

# %% [markdown]
# #### P-value is less than 0.05, so we reject the null hypothesis.
# #### That is, the percentage of women that spend more than 10000 is not 35%

# %% [markdown]
# ## Two Sample test for Means
# Is the average purchase made by men and women of the age 18-25 same?

# %%
#null hypothesis - average purchase made are equal 
#alternate hypothesis - average purchase made are not equal

# %%
data_male=data.loc[(data['Gender']==1) & (data['Age']==1)]
data_female=data.loc[(data['Gender']==0) & (data['Age']==1)]

# %%
#sample variance
print('data_male(variance): ',data_male['Purchase'].var())
print('data_female(variance): ',data_female['Purchase'].var())
# Out:
# data_male(variance):  25462982.028337173
# data_female(variance):  21559037.293336354

# %%
#sample mean
print('data_male(mean): ',data_male['Purchase'].mean())
print('data_female(mean): ',data_female['Purchase'].mean())
# Out:
# data_male(mean):  9440.512275679841
# data_female(mean):  8406.001601888542

# %%
#two sample t-test for unequal variances
from scipy.stats import ttest_ind

t_stat,p_value=ttest_ind(data_male['Purchase'],data_female['Purchase'],equal_var=False)
print('t_stat : ',t_stat)
print('p_value : ',p_value)
# Out:
# t_stat :  20.614153501329056
# p_value :  1.610443940866231e-93

# %% [markdown]
# #### P-value is greater than 0.05, so we accept null hypothesis.
# #### That is, the average purchase made by men and women of the age 18-25 are same

# %% [markdown]
# ## Two Sample test for Proportion¶
# Is the percentage of men who have spend more than 10000 same for the ages 18-25 and 26-35

# %%
#null hypothesis - Percentage of the men in the age groups is same
#alternate hypothesis - Percentage of the men in the age groups is not same

# %%
data_age1 = data.loc[(data['Age'] == 1) & (data['Purchase'] > 10000)]
data_age2 = data.loc[(data['Age'] == 2) & (data['Purchase'] > 10000)]

# %%
data_age1.shape
# Out:
# (16610, 12)

# %%
data_age2.shape
# Out:
# (36333, 12)

# %%
len(data_age1)
# Out:
# 16610

# %%
len(data_age2)
# Out:
# 36333

# %%
data_age1_samp=data_age1.sample(1000,random_state=0)
data_age2_samp=data_age2.sample(1000,random_state=0)

# %%
count = [(data_age1_samp['Gender'] == 1).sum(), (data_age2_samp['Gender'] == 1).sum()]
print(count)
no_obs = [(len(data_age1_samp)), len(data_age2_samp)]
print(no_obs)
# Out:
# [790, 811]
# [1000, 1000]

# %%
from statsmodels.stats.proportion import proportions_ztest
stat_2sample,p_value=proportions_ztest(count=count,nobs=no_obs,value=0,alternative='two-sided',prop_var=False)
print(stat_2sample,p_value)
# Out:
# -1.1750387227102372 0.2399792241715063

# %% [markdown]
# #### P value is more than 0.05, so accept the null hypothesis.
#
# #### Therefore, Percentage of the men in  both the age groups who have spent more than 10000 is same
